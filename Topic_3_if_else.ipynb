# %%
usernames = ["joe", "jane", "doe"]
passwords = ["12345678", "password", "87654321"]
u = input("please enter your username: ")
if u in usernames:
    print(f"ok {u} please enter your password")
    p = input("please enter your password: ")
    
else:
    print("wrong username")
# Out:
# wrong username

# %%
## Entered by Joe
names = ['bob', 'timmy', 'steve']
for name in names:
    print('hello' + ' ' + name.title() + ' would you like to make some music?')
    print('Sounds good!')
for name in names:
    if name == 'timmy':
        print(name.title() + " let's collab")


## HW question 9
# Out:
# hello Bob would you like to make some music?
# Sounds good!
# hello Timmy would you like to make some music?
# Sounds good!
# hello Steve would you like to make some music?
# Sounds good!
# Timmy let's collab

# %%
name = input("Enter your name: ")
names = [name]
for name in names:
    if name == 'timmy':
        print(name.title() + " let's collab")
    else:
        print('hello' + ' ' + name.title() + ' would you like to make some music?')
# Out:
# Timmy let's collab

# %%
age = int(input("Enter your age: "))
while age < 70:
    print("Welcome")
    age = int(input("Enter your age: "))
else:
    print("STOP, ASSISTANCE REQUIRED")
# Out:
# Welcome
# STOP, ASSISTANCE REQUIRED

# %%
names2 = []
name2 = input("Enter your name: ")
while name2 != 'done':
    if name2.title() != 'Sam':
        names2.append(name2.title())
        print(f'Guestlist: {names2}')
        name2 = input("Enter your name: ")
    else:
        print('Sorry, Sam is not allowed')
        name2 = input("Enter your name: ")
    if name2 == 'done':
        print(f'Final Guestlist: {names2}')
        break
# Out:
# Guestlist: ['John']
# Guestlist: ['John', 'James']
# Guestlist: ['John', 'James', 'Kyle']
# Guestlist: ['John', 'James', 'Kyle', 'Cartman']
# Guestlist: ['John', 'James', 'Kyle', 'Cartman', 'Kenny']
# Guestlist: ['John', 'James', 'Kyle', 'Cartman', 'Kenny', 'Tweak']
# Guestlist: ['John', 'James', 'Kyle', 'Cartman', 'Kenny', 'Tweak', 'Mr. Mackey']
# Guestlist: ['John', 'James', 'Kyle', 'Cartman', 'Kenny', 'Tweak', 'Mr. Mackey', 'Randy']
# Guestlist: ['John', 'James', 'Kyle', 'Cartman', 'Kenny', 'Tweak', 'Mr. Mackey', 'Randy', 'Sharon']
# Guestlist: ['John', 'James', 'Kyle', 'Cartman', 'Kenny', 'Tweak', 'Mr. Mackey', 'Randy', 'Sharon', 'Gerald']
# Guestlist: ['John', 'James', 'Kyle', 'Cartman', 'Kenny', 'Tweak', 'Mr. Mackey', 'Randy', 'Sharon', 'Gerald', 'Sheila']
# Guestlist: ['John', 'James', 'Kyle', 'Cartman', 'Kenny', 'Tweak', 'Mr. Mackey', 'Randy', 'Sharon', 'Gerald', 'Sheila', 'Wendy']
# ...
