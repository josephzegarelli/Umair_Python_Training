# %%
fruits = ["apple", "banana", "cherry"]  # list of strings
prices = (0.99, 0.59, 0.79)               # tuple of floats

# %%
fruits = {
    "apple": 0.99,
    "banana": 0.59,
    "cherry": 0.79,
    
}
