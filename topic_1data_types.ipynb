# %%
name = "joe" # string
age = 30      # integer
height = 5.9  # float
is_student = False  # boolean

# %%
# everything is class in python

name.upper()
# Out:
# 'JOE'

# %%
age.bit_length()
# Out:
# 5

# %%
name = "umair"
age = 31
print(f"your name is {name} and yoru age is {age}")
# Out:
# your name is umair and yoru age is 31

# %%
input('Joe':27)
# Out:
#   Cell In[1], line 1
#     input('Joe':27)
#                ^
# SyntaxError: invalid syntax

# %%
name = input("please neter your name")
age = input("please enter your age")
print(f"your name is {name} and yoru age is {age}")
# Out:
# your name is joe and yoru age is 20

# %%
name
# Out:
# 'umair'

# %%
## please use input to get number 1 and input to get number 2
## print their sum and product

# %%
x = input("please enter first number: ")
y = input("please enter second number: ")
print("sum is:", int(x) +  int(y))
print("product is:", int(x) *  int(y))
# Out:
# sum is: 13
# product is: 40
